# %%
#! usr/bin/python
from astropy import units as u
quantity = 100.0 * u.meter # here the constant meter is called from the subpackage units that we renamed u.
valeur = quantity.value
unite = quantity.unit


print (quantity)
print (valeur)
print (unite)


quantity2=(quantity.to(u.parsec))
print (quantity2)
# Out:
# 100.0 m
# 100.0
# m
# 3.240779289444365e-15 pc

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
x = [0,1,2]
ax.plot(x,2*np.array(x))
